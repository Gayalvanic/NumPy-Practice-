# %% [markdown]
# ### 1. Create an array of numbers from 1 to 20 and extract only the multiples of 3.
# ### 2. Given arr = np.array([5, 10, 15, 20, 25, 30]), replace all values greater than 15 with 999.
# ### 3. Create a 2D array with shape (4,4) where the diagonal contains values 10, 20, 30, 40.
# ### 4. From the array
# ### A = [[1, 2, 3],
# ###      [4, 5, 6],
# ###      [7, 8, 9]]
# ### extract the corner values: 1, 3, 7, 9.
#
# ### 5. Create a 1D array of 10 random integers between 0–50 and replace numbers between 10 and 20 (inclusive) with -5.
# ### 6. Convert np.arange(9) into a 3×3 matrix without using reshape().
# ### 7. Reverse a 1D NumPy array using slicing.
# ### 8. Swap row 0 and row 2 in a 3×3 array without using loops.
# ### 9. Create a (3,5) array of random integers and set the minimum value of each column to 0.
# ### 10. Count how many numbers in a random array of size 100 are divisible by both 2 and 5.
# ### 11. Create a 2D array of shape (3,4) filled with numbers from 0 to 11. (Hint: arange + reshape)
# ### 12. Replace all even numbers in an array with -1.
# ### 13. Given arr = np.array([1,2,3,4,5]), convert it into a column vector of shape (5,1).
# ### 14. Create an array of 10 random integers between 1 and 100.
# ### 15. Extract all elements at odd indices from a 1D array.
