# %% [markdown]
# ### 1. Given
# ### arr = np.array([[10, 20, 30],
# ###                 [40, 50, 60],
# ###                 [70, 80, 90]])
# ### extract the middle column.
# ### 2. From a 1D array of 15 elements, extract elements at indices divisible by 3.
# ### 3. Split np.arange(16) into 4 equal sub-arrays.
# ### 4. Concatenate two arrays vertically (axis=0) where both have shape (2,3).
# ### 5. Given a 2D array, extract only the last row and keep it 2D (not flattened).
# ### 6. Using slicing only, reverse each row of a 2D array.
# ### 7. Add a column vector [100, 200, 300] to every column of this array using broadcasting:
# ###      A = [[1, 2, 3],
# ###          [4, 5, 6],
# ###          [7, 8, 9]]
# ### 8. From a random array of size 30, replace all numbers less than the mean with 0.
# ### 9. Given a 2D array, count how many elements are greater than 50 using boolean masking.
# ### 10. Convert a 1D array of length 12 into a (3,4) matrix without using reshape().
# ### 11. Swap column 0 and column 2 of a 2D array without loops.
# ### 12. Using NumPy only, find the row-wise sum of a 2D array.
# ### 13. From a 2D array, extract all elements that are even.
# ### 14. Create a (4,4) array and set the last column to 1 using slicing.
# ### 15. Given two arrays of shape (3,1) and (1,4), add them and print the resulting shape.### 6. Given arr = np.array([[1,2,3],[4,5,6]]), extract the second column.
# ### 16. Split the array np.arange(12) into 3 equal sub-arrays.
# ### 17. Concatenate two 2D arrays horizontally (axis=1).
# ### 18. Using broadcasting, add a row vector [10,20,30] to every row of a 2D array:
# ###      A = [[1,2,3],
# ###           [4,5,6],
# ###           [7,8,9]]
# ### 19. Use boolean masking to extract all values > 50 from a random array of size 20.
# ### 20. Given arr = np.array([[1,2,3],[4,5,6]]), extract the second column.
